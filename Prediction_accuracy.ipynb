# %%
import os
import numpy as np
import pyedflib
from glob import glob

# Function to read txt file data
def read_txt_file(filepath):
    with open(filepath, 'r') as file:
        data = np.loadtxt(file)
    return data

# Function to write data to EDF
def write_to_edf(output_path, signals, signal_labels, sampling_frequency):
    num_signals = len(signals)
    
    # Initialize EdfWriter with the required number of channels (n_channels)
    edf_writer = pyedflib.EdfWriter(output_path, n_channels=num_signals, file_type=pyedflib.FILETYPE_EDFPLUS)
    
    # Prepare signal headers
    signal_headers = []
    for i in range(num_signals):
        header = {
            'label': signal_labels[i],
            'dimension': 'uV',
            'sample_rate': sampling_frequency,
            'physical_min': np.min(signals[i]),
            'physical_max': np.max(signals[i]),
            'digital_min': -32768,
            'digital_max': 32767
        }
        signal_headers.append(header)
    
    # Set signal headers in the EDF writer
    edf_writer.setSignalHeaders(signal_headers)
    
    # Write the signals to the EDF file
    edf_writer.writeSamples(signals)
    
    # Close the EDF writer properly
    edf_writer.close()

# Main function to process all patients and convert txt to edf
def convert_txt_to_edf(base_folder, output_folder, sampling_frequency=128):
    # Count all .edf files in output folder before conversion
    all_edf_files = glob(os.path.join(output_folder, '*.edf'))
    print(f"Found {len(all_edf_files)} existing .edf files in the output folder.")
    
    # Check if output folder exists, create if it doesn't
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    patients = os.listdir(base_folder)
    
    for patient in patients:
        patient_folder = os.path.join(base_folder, patient)
        
        if os.path.isdir(patient_folder):
            # Collecting all electrode files for this patient
            electrode_files = sorted([f for f in os.listdir(patient_folder) if f.endswith('.txt')])
            
            signals = []
            signal_labels = []
            
            # Read data from all electrode .txt files
            for electrode_file in electrode_files:
                electrode_path = os.path.join(patient_folder, electrode_file)
                data = read_txt_file(electrode_path)
                signals.append(data)
                signal_labels.append(os.path.splitext(electrode_file)[0])  # Use the file name as the label
                
            # Output path for EDF
            output_edf_path = os.path.join(output_folder, f"{patient}.edf")
            
            # Write the data to EDF file
            write_to_edf(output_edf_path, signals, signal_labels, sampling_frequency)
            print(f"Converted {patient} to EDF.")
            
    # After conversion, print the number of .edf files in the output folder again
    all_edf_files = glob(os.path.join(output_folder, '*.edf'))
    print(f"Total .edf files in the output folder after conversion: {len(all_edf_files)}")

# Set your base folder and output folder paths
base_folder = "/Users/kanisha/Downloads/EEG_data1/Eyes_closed"
output_folder = "/Users/kanisha/Downloads/Files" 

# Convert the files
convert_txt_to_edf(base_folder, output_folder)
# Out:
# Found 92 existing .edf files in the output folder.
# Converted Paciente62 to EDF.
# Converted Paciente91 to EDF.
# Converted Paciente65 to EDF.
# Converted Paciente53 to EDF.
# Converted Paciente54 to EDF.
# Converted Paciente38 to EDF.
# Converted Paciente31 to EDF.
# Converted Paciente36 to EDF.
# Converted Paciente55 to EDF.
# Converted Paciente52 to EDF.
# Converted Paciente64 to EDF.
# Converted Paciente90 to EDF.
# Converted Paciente63 to EDF.
# Converted Paciente37 to EDF.
# Converted Paciente30 to EDF.
# Converted Paciente39 to EDF.
# Converted Paciente23 to EDF.
# Converted Paciente24 to EDF.
# Converted Paciente8 to EDF.
# Converted Paciente1 to EDF.
# Converted Paciente12 to EDF.
# Converted Paciente15 to EDF.
# Converted Paciente6 to EDF.
# Converted Paciente41 to EDF.
# Converted Paciente79 to EDF.
# Converted Paciente46 to EDF.
# Converted Paciente70 to EDF.
# Converted Paciente84 to EDF.
# Converted Paciente48 to EDF.
# Converted Paciente83 to EDF.
# Converted Paciente77 to EDF.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 0 (C3) is -35.974998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -35.9749, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 0 (C3) is 28.176001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 28.17600, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 3 (F1) is -48.308998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -48.3089, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 4 (F2) is 35.467999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 35.46799, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 5 (F3) is 32.910999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 32.91099, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 6 (F4) is -40.976002, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -40.9760, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 6 (F4) is 39.023998, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 39.02399, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 7 (F7) is -32.915001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -32.9150, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 7 (F7) is 40.514999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 40.51499, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 8 (F8) is -39.089001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -39.0890, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 9 (Fp1) is -48.308998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -48.3089, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 10 (Fp2) is 35.467999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 35.46799, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 11 (Fz) is 33.498001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 33.49800, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 12 (O1) is -36.363998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -36.3639, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 13 (O2) is -43.665001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -43.6650, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 13 (O2) is 54.912998, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 54.91299, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 14 (P3) is -37.852001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -37.8520, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 14 (P3) is 49.352001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 49.35200, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 15 (P4) is -32.849998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -32.8499, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 15 (P4) is 46.376999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 46.37699, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 16 (Pz) is -40.514999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -40.5149, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 16 (Pz) is 52.237999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 52.23799, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 18 (T4) is -32.101002, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -32.1010, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 19 (T5) is -29.412001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -29.4120, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 20 (T6) is 47.949001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 47.94900, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 0 (C3) is -31.683001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -31.6830, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 0 (C3) is 42.574001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 42.57400, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 1 (C4) is -32.228001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -32.2280, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 1 (C4) is 42.144001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 42.14400, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 2 (Cz) is 42.442001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 42.44200, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 3 (F1) is 61.699001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 61.69900, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 4 (F2) is 54.304001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 54.30400, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 5 (F3) is -36.151001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -36.1510, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 6 (F4) is -30.150999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -30.1509, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 7 (F7) is 65.621002, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 65.62100, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 8 (F8) is 44.153999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 44.15399, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 9 (Fp1) is 61.699001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 61.69900, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 10 (Fp2) is 54.304001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 54.30400, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 11 (Fz) is -33.009998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -33.0099, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 12 (O1) is -76.126999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -76.1269, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 12 (O1) is 61.015999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 61.01599, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 13 (O2) is -80.911003, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -80.9110, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 14 (P3) is -56.632999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -56.6329, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 14 (P3) is 44.376999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 44.37699, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 15 (P4) is -49.750999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -49.7509, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 15 (P4) is 50.745998, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 50.74599, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 16 (Pz) is -50.318001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -50.3180, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 16 (Pz) is 58.223999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 58.22399, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 17 (T3) is -37.067001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -37.0670, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 17 (T3) is 45.932999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 45.93299, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 18 (T4) is -27.249001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -27.2490, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 19 (T5) is -74.081001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -74.0810, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 19 (T5) is 51.771999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 51.77199, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 20 (T6) is -69.773003, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -69.7730, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 20 (T6) is 49.644001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 49.64400, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 0 (C3) is -35.196999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -35.1969, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 0 (C3) is 29.257999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 29.25799, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 1 (C4) is -30.349001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -30.3490, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 1 (C4) is 33.459999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 33.45999, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 2 (Cz) is -31.974001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -31.9740, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 4 (F2) is -21.674999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -21.6749, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 5 (F3) is -36.006001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -36.0060, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 5 (F3) is 34.525002, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 34.52500, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 6 (F4) is 32.039001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 32.03900, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 7 (F7) is -38.900002, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -38.9000, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 7 (F7) is 39.741001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 39.74100, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 10 (Fp2) is -21.674999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -21.6749, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 11 (Fz) is 35.820999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 35.82099, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 12 (O1) is 28.570999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 28.57099, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 13 (O2) is -30.540001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -30.5400, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 13 (O2) is 26.603001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 26.60300, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 14 (P3) is -33.206001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -33.2060, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 14 (P3) is 32.507999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 32.50799, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 16 (Pz) is -34.717999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -34.7179, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 19 (T5) is 25.615999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 25.61599, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 20 (T6) is 29.679001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 29.67900, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 0 (C3) is 26.476999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 26.47699, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 1 (C4) is 27.683001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 27.68300, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 2 (Cz) is -17.561001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -17.5610, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 2 (Cz) is 31.219999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 31.21999, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 3 (F1) is -82.352997, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -82.3529, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 3 (F1) is 103.919998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to 103.9199, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 4 (F2) is -79.803001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -79.8030, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 4 (F2) is 99.507004, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 99.50700, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 5 (F3) is -32.455002, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -32.4550, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 6 (F4) is 38.646999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 38.64699, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 7 (F7) is -34.044998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -34.0449, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 7 (F7) is 24.207001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 24.20700, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 9 (Fp1) is -82.352997, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -82.3529, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 9 (Fp1) is 103.919998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to 103.9199, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 10 (Fp2) is -79.803001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -79.8030, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 10 (Fp2) is 99.507004, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 99.50700, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 11 (Fz) is 38.235001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 38.23500, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 12 (O1) is 27.618999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 27.61899, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 14 (P3) is -24.580999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -24.5809, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 15 (P4) is 32.849998, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 32.84999, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 16 (Pz) is -21.191999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -21.1919, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 16 (Pz) is 30.016001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 30.01600, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 17 (T3) is -20.419001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -20.4190, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 17 (T3) is 20.160999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 20.16099, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 19 (T5) is -26.471001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -26.4710, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 20 (T6) is 24.025999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 24.02599, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 0 (C3) is 34.060001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 34.06000, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 1 (C4) is 31.492001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 31.49200, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 2 (Cz) is 35.122002, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 35.12200, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 3 (F1) is -40.195999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -40.1959, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 4 (F2) is 40.394001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 40.39400, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 5 (F3) is -38.308998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -38.3089, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 5 (F3) is 31.934999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 31.93499, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 6 (F4) is -35.749001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -35.7490, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 6 (F4) is 34.783001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 34.78300, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 7 (F7) is -20.452999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -20.4529, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 7 (F7) is 21.294001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 21.29400, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 8 (F8) is 20.323999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 20.32399, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 9 (Fp1) is -40.195999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -40.1959, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 10 (Fp2) is 40.394001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 40.39400, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 13 (O2) is -34.348999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -34.3489, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 13 (O2) is 28.507999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 28.50799, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 15 (P4) is 34.783001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 34.78300, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 16 (Pz) is -35.683998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -35.6839, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 16 (Pz) is 32.915001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 32.91500, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 18 (T4) is 21.016001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 21.01600, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# ...
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 3 (F1) is -42.926998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -42.9269, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 3 (F1) is 46.828999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 46.82899, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 4 (F2) is -52.216999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -52.2169, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 4 (F2) is 52.216999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 52.21699, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 5 (F3) is 44.682999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 44.68299, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 6 (F4) is -61.835999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -61.8359, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 6 (F4) is 55.071999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 55.07199, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 8 (F8) is 43.837002, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 43.83700, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 9 (Fp1) is -42.926998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -42.9269, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 9 (Fp1) is 46.828999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 46.82899, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 10 (Fp2) is -52.216999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -52.2169, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 10 (Fp2) is 52.216999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 52.21699, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 11 (Fz) is -65.025002, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -65.0250, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 12 (O1) is 52.381001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 52.38100, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 14 (P3) is -37.078999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -37.0789, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 15 (P4) is -36.537998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -36.5379, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 15 (P4) is 54.807999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 54.80799, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 17 (T3) is -44.573002, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -44.5730, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 17 (T3) is 36.585999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 36.58599, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 18 (T4) is -39.683998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -39.6839, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 18 (T4) is 33.301998, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 33.30199, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 19 (T5) is 40.394001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 40.39400, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 20 (T6) is -41.473999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -41.4739, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 20 (T6) is 58.526001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 58.52600, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 1 (C4) is -40.507999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -40.5079, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 1 (C4) is 33.143002, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 33.14300, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 3 (F1) is 30.853001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 30.85300, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 6 (F4) is -35.122002, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -35.1220, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 7 (F7) is -18.743999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -18.7439, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 8 (F8) is 17.410999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 17.41099, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 9 (Fp1) is 30.853001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 30.85300, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 11 (Fz) is -32.744999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -32.7449, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 11 (Fz) is 45.033001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 45.03300, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 13 (O2) is 22.264999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 22.26499, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 14 (P3) is -31.683001, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -31.6830, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 14 (P3) is 33.714001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 33.71400, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 15 (P4) is -36.245998, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -36.2459, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 15 (P4) is 33.657001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 33.65700, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 17 (T3) is 23.059999, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 23.05999, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:124: UserWarning: Physical minimum for channel 18 (T4) is -25.844999, which has 10 chars, however, EDF+ can only save 8 chars, will be truncated to -25.8449, some loss of precision is to be expected
#   warnings.warn('Physical minimum for channel {} ({}) is {}, which has {} chars, '\
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pyedflib/edfwriter.py:131: UserWarning: Physical maximum for channel 19 (T5) is 30.065001, which has 9 chars, however, EDF+ can only save 8 chars, will be truncated to 30.06500, some loss of precision is to be expected.
#   warnings.warn('Physical maximum for channel {} ({}) is {}, which has {} chars, '\

# %%
from glob import glob
import os
import mne
import numpy as np
import pandas
import matplotlib.pyplot as plt

# %%
all_edf_files = glob(os.path.join(output_folder, '*.edf'))
print(f"Found {len(all_edf_files)} existing .edf files in the output folder.")
# Out:
# Found 92 existing .edf files in the output folder.

# %%
all_edf_files[0]
# Out:
# '/Users/kanisha/Downloads/Files/Paciente20.edf'

# %%
import os
from glob import glob

# Function to extract patient number from file path
def get_patient_number(file_path):
    # Split the file path to get the file name (e.g., 'paciente1.edf')
    file_name = os.path.basename(file_path)
    # Extract the number after 'Paciente' and before the file extension
    patient_number = int(file_name.replace('Paciente', '').split('.')[0])  
    return patient_number

# Path to your EDF files
all_file_path = glob('/Users/kanisha/Downloads/Files/*.edf')

# Filter for healthy patients (81 to 92)
healthy_file_path = [i for i in all_file_path if 81 <= get_patient_number(i) <= 92]

# Filter for AD patients (1 to 80)
patient_file_path = [i for i in all_file_path if 1 <= get_patient_number(i) <= 80]

# Print the number of files in each category
print("Total files:", len(all_file_path))
print("Healthy patients (81-92):", len(healthy_file_path))
print("AD patients (1-80):", len(patient_file_path))

data_list = control_epochs_array + patient_epochs_array
label_list = control_epoch_labels + patient_epoch_labels
# dividing the dataset so that there is a balanced distribution of data(not randomly)
# Out:
# Total files: 92
# Healthy patients (81-92): 12
# AD patients (1-80): 80

# %%
import mne

def read_data(file_path, filter_data=True, l_freq=0.5, h_freq=30):
    try:
        # Read the raw EEG data
        data = mne.io.read_raw_edf(file_path, preload=True)
        
        # Set the EEG reference to the average of all channels
        data.set_eeg_reference()

        # Apply filter if specified
        if filter_data:
            data.filter(l_freq=l_freq, h_freq=h_freq)

        # Define the list of required scalp channels
        required_channels = ['Fp1', 'Fp2', 'F3', 'F4', 'F7', 'F8', 'Fz', 'C3', 'C4', 'Cz', 
                             'P3', 'P4', 'Pz', 'T3', 'T4', 'T5', 'T6', 'O1', 'O2']

        # Check if all required channels are in the data
        available_channels = [ch for ch in required_channels if ch in data.info['ch_names']]
        if len(available_channels) != len(required_channels):
            print(f"Warning: Some channels are missing from the data. Available channels: {available_channels}")

        # Pick only the available channels
        data.pick_channels(available_channels)

        # Create epochs of 1 second duration with 0.5-second overlap
        epochs = mne.make_fixed_length_epochs(data, duration=1, overlap=0.5)

        # Extract the data from the epochs into a NumPy array
        array = epochs.get_data()
        
        return array
    
    except Exception as e:
        print(f"Error reading the file {file_path}: {e}")
        return None

# %%
# Assuming the healthy_file_path list is already populated with valid paths
# and the read_data function is properly defined

# Read data from the first file in the healthy_file_path list
sample_data = read_data(healthy_file_path[0])

# Check if the data is successfully read
if sample_data is not None:
    print("Sample Data Shape:", sample_data.shape)
else:
    print("Error reading the data from the file.")
# Out:
# Extracting EDF parameters from /Users/kanisha/Downloads/Files/Paciente81.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1023  =      0.000 ...     7.992 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 845 samples (6.602 s)
#
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# Not setting metadata
# 15 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 15 events and 128 original time points ...
# 0 bad epochs dropped
# Sample Data Shape: (15, 19, 128)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s

# %%
sample_data.shape
# Out:
# (15, 19, 128)

# %%
# %%capture
# this will hide the output becoz it will be very long
control_epochs_array = [read_data(i) for i in healthy_file_path]
patient_epochs_array = [read_data(i) for i in patient_file_path]

# %%
control_epochs_array[0].shape,control_epochs_array[1].shape
# Out:
# ((15, 19, 128), (15, 19, 128))

# %%
control_epoch_labels = [len(i)*[0] for i in control_epochs_array]
patient_epoch_labels = [len(i)*[1] for i in patient_epochs_array]
len(control_epoch_labels),len(patient_epoch_labels)
# Out:
# (12, 80)

# %%
data_list = control_epochs_array + patient_epochs_array
label_list = control_epoch_labels + patient_epoch_labels

# %%
group_list = [[i]* len(j)  for i,j in enumerate(data_list)]
len(group_list)
# Out:
# 92

# %%
data_array = np.vstack(data_list)
label_array = np.hstack(label_list)
group_array = np.hstack(group_list)
print(data_array.shape,label_array.shape,group_array.shape)
# Out:
# (1380, 19, 128) (1380,) (1380,)

# %%
from scipy import stats
import numpy as np

def mean(x):
    return np.mean(x, axis=-1)

def std(x):
    return np.std(x, axis=-1)

def ptp(x):
    return np.ptp(x, axis=-1)

def var(x):
    return np.var(x, axis=-1)

def minim(x):
    return np.min(x, axis=-1)

def maxim(x):
    return np.max(x, axis=-1)

def argminim(x):
    return np.argmin(x, axis=-1)

def argmaxim(x):
    return np.argmax(x, axis=-1)    

def res(x):
    return np.sqrt(np.mean(x**2, axis=-1))

def abs_diff_signal(x):
    return np.sum(np.abs(np.diff(x, axis=-1)), axis=-1)

def kurtosis(x):
    return stats.kurtosis(x, axis=-1)

def skewness(x):
    return stats.skew(x, axis=-1)

def concatenate_feature(x):
    return np.concatenate((mean(x), std(x), ptp(x), var(x), minim(x), maxim(x),
                           argminim(x), argmaxim(x), res(x), abs_diff_signal(x),
                           kurtosis(x), skewness(x)), axis=-1)

# %%
features = []
for d in data_array:
    features.append(concatenate_feature(d))  # Correct function call

# %%
features_array = np.array(features)
features_array.shape
# Out:
# (1380, 228)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold,GridSearchCV

# %%
# Flatten the data
data_array_2d = data_array.reshape(data_array.shape[0], -1)
gscv.fit(data_array_2d, label_array)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('clf', LogisticRegression())]),
#              n_jobs=12, param_grid={'clf__C': [0.1, 0.5, 0.7, 1, 3, 5, 7]})

# %%
clf = LogisticRegression()

# Define the cross-validation strategy
gkf = GroupKFold(n_splits=5)

# Create a pipeline with a scaler and classifier
pipe = Pipeline([
    ('scaler', StandardScaler()),  # Apply standard scaling
    ('clf', clf)  # Use Logistic Regression as classifier
])

# Define the hyperparameter grid to search for the best hyperparameters
param_grid = {'clf__C': [0.1, 0.5, 0.7, 1, 3, 5, 7]}  # Regularization strength for logistic regression

# Perform grid search with cross-validation using GroupKFold
gscv = GridSearchCV(pipe, param_grid, cv=gkf, n_jobs=12)  # n_jobs=12 means using 12 cores for parallel processing

# Fit the model on the features, labels, and groups
gscv.fit(features_array, label_array, groups=group_array)
# Out:
# GridSearchCV(cv=GroupKFold(n_splits=5),
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('clf', LogisticRegression())]),
#              n_jobs=12, param_grid={'clf__C': [0.1, 0.5, 0.7, 1, 3, 5, 7]})

# %%
gscv.best_score_ #0.92 before
# Out:
# np.float64(0.9221052631578948)
